# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from waveoptics.plots.plots import complex_imshow

# %%
cplx = np.random.randn(25, 25) + 1j * np.random.randn(25, 25)
fig, ax = complex_imshow(cplx, colorbar=True)
ax.set_title('test')
ax.set_xlabel('a')
# Out:
# Text(0.5, 0, 'a')
